# %%
import matplotlib.pyplot as plt
from PIL import Image

img = Image.open("testdata/IMG_20240130_205027_316.jpg")

plt.imshow(img)

# %%
from src.components import FileCode, CaesarCipher

result = FileCode.code(img.tobytes(), 45, 256, CaesarCipher.encode_caesar)
plt.imshow(Image.frombytes(img.mode, img.size, result))

# %%
result = FileCode.code(img.tobytes(), 234, 256, CaesarCipher.encode_caesar, "encode")
plt.imshow(Image.frombytes(img.mode, img.size, result))

# %%
result = FileCode.code(result, 234, 256, CaesarCipher.decode_caesar, "decode")
plt.imshow(Image.frombytes(img.mode, img.size, result))
