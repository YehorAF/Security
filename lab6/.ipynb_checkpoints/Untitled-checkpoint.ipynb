# %%
from Crypto.PublicKey import RSA

key = RSA.generate(1024)
key.public_key().export_key(), key.export_key()
# Out:
# (b'-----BEGIN PUBLIC KEY-----\nMIGfMA0GCSqGSIb3DQEBAQUAA4GNADCBiQKBgQDKuAdPaafmO2UtO49wMvC9ACrX\nyTKn3ufmPq3zrF58GSK0eFecGsxcQklGHWQsMDY73lc61b7Id+UlXa4cBoukan4V\nUFl03FqP6LYLQqAogpOdLEY49QqJBHIxHNGweYrePzB6VHRwBOK56yo0I6XrJrZU\nJQaqqYvK7o4DImOU9QIDAQAB\n-----END PUBLIC KEY-----',
# ...

# %%
from src.components import AbsRSA

cipher = AbsRSA()
pub, prv = cipher.gen_keys(1024)

text = "привіт! як у тебе справи?"
enc_text = cipher.encrypt(pub, text.encode())
dec_text = cipher.decrypt(prv, enc_text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_101607/695556261.py in <module>
#       6 text = "привіт! як у тебе справи?"
#       7 enc_text = cipher.encrypt(pub, text.encode())
# ----> 8 dec_text = cipher.decryot(prv, enc_text)
#
# AttributeError: 'AbsRSA' object has no attribute 'decryot'
